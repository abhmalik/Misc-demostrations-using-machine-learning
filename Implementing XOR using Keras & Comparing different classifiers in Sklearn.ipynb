# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression, SGDClassifier, LinearRegression
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

import tensorflow as tf

# %% [markdown]
# ### Comparing Different Classifiers in Sklearn

# %%
def con1(x,y):
    if y>=0.2*np.sin(10*x)+x:
        rv = 1
    else:
        rv = -1
    return rv

def con2(x,y):
    if (x+0.5)**2+(y-0.5)**2<= 0.1:
        rv = -2
    else:
        rv = 0
    return rv

def con3(x,y):
    if (x-0.5)**2+(y+0.5)**2<= 0.1:
        rv = 2
    else:
        rv = 0
    return rv

length=1000
xyset = 3.*(np.random.rand(length,2)-[0.5,0.5])
classes=[con1(xyset[i,0],xyset[i,1])+con2(xyset[i,0],xyset[i,1])+con3(xyset[i,0],xyset[i,1]) for i in range(len(xyset))]

plt.scatter(xyset[:,0],xyset[:,1],c=classes)

# %%
x_train, x_test, y_train, y_test = train_test_split(xyset, classes, test_size=0.2, random_state=42)

# %%
clf1 = SVC()

clf1.fit(x_train, y_train)
score1 = clf1.score(x_test, y_test)
print('Score using SVC:', score1)

pred1 = clf1.predict(x_test)
plt.scatter(x_test[:,0],x_test[:,1],c=pred1)
# Out:
# Score using SVC: 0.92
# C:\Users\vip\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
clf2 = RandomForestClassifier()

clf2.fit(x_train, y_train)
score2 = clf2.score(x_test, y_test)
print('Score using RF Classifier:', score2)

pred2 = clf2.predict(x_test)
plt.scatter(x_test[:,0],x_test[:,1],c=pred2)
# Out:
# Score using RF Classifier: 0.995
# C:\Users\vip\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
clf3 = DecisionTreeClassifier()

clf3.fit(x_train, y_train)
score3 = clf3.score(x_test, y_test)
print('Score using DT Classifier:', score3)

pred3 = clf3.predict(x_test)
plt.scatter(x_test[:,0],x_test[:,1],c=pred3)
# Out:
# Score using DT Classifier: 0.99

# %%
clf4 = AdaBoostClassifier()
clf4.fit(x_train, y_train)
score4 = clf4.score(x_test, y_test)
print('Score using AdaBoost Classifier:', score4)

pred4 = clf4.predict(x_test)
plt.scatter(x_test[:,0],x_test[:,1],c=pred4)
# Out:
# Score using AdaBoost Classifier: 0.865

# %%
## Part 1.c)
score = []
max_depths = range(1,20,1)

for max_depth in max_depths:
    
    clf5 = DecisionTreeClassifier(max_depth = max_depth)
    clf5.fit(x_train, y_train)
    score5 = clf5.score(x_test, y_test)
    #print('Score using DT Classifier with max:', score3)
    score.append(score5)

plt.plot(max_depths, score, label='Max Depth of the Decision Tree Classsifier vs Accuracy')
plt.legend()
plt.xlabel('Max Depth of the Decision Tree Classsifier')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# As we can see, max_depth = 10 or 11 will be best to use as performance stopped improving after this point

# %% [markdown]
# ### Implementing XOR problem using Keras:

# %%
# Different states of the XOR gate
training_data = np.array([[0,0],[0,1],[1,0],[1,1]])
# The labels in the same order
target_data = np.array([[0],[1],[1],[0]])

# %%
# Case1: Model with no hidden layer
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

model.compile(loss='mean_squared_error',
              optimizer='adam', metrics=['accuracy'])

model.fit(training_data, target_data, nb_epoch=500, verbose=2)
# Out:
# WARNING:tensorflow:The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Epoch 1/500
#  - 0s - loss: 0.2601 - acc: 0.7500
# Epoch 2/500
#  - 0s - loss: 0.2600 - acc: 0.5000
# Epoch 3/500
#  - 0s - loss: 0.2600 - acc: 0.5000
# Epoch 4/500
#  - 0s - loss: 0.2600 - acc: 0.5000
# Epoch 5/500
#  - 0s - loss: 0.2599 - acc: 0.5000
# Epoch 6/500
#  - 0s - loss: 0.2599 - acc: 0.5000
# Epoch 7/500
#  - 0s - loss: 0.2599 - acc: 0.5000
# Epoch 8/500
#  - 0s - loss: 0.2598 - acc: 0.5000
# Epoch 9/500
#  - 0s - loss: 0.2598 - acc: 0.5000
# Epoch 10/500
#  - 0s - loss: 0.2598 - acc: 0.5000
# Epoch 11/500
#  - 0s - loss: 0.2597 - acc: 0.5000
# Epoch 12/500
#  - 0s - loss: 0.2597 - acc: 0.5000
# Epoch 13/500
#  - 0s - loss: 0.2597 - acc: 0.5000
# Epoch 14/500
#  - 0s - loss: 0.2596 - acc: 0.5000
# Epoch 15/500
#  - 0s - loss: 0.2596 - acc: 0.5000
# Epoch 16/500
#  - 0s - loss: 0.2596 - acc: 0.5000
# Epoch 17/500
#  - 0s - loss: 0.2595 - acc: 0.5000
# Epoch 18/500
# ...

# %%
# Model was not able to predict properly when we used no hidden layers
print(model.predict(training_data).round())
# Out:
# [[1.]
#  [1.]
#  [0.]
#  [0.]]

# %%
# With 1 hidden layer
model2 = tf.keras.models.Sequential()
model2.add(tf.keras.layers.Dense(8, input_dim=2, activation='relu'))
model2.add(tf.keras.layers.Dense(1, activation='sigmoid'))

model2.compile(loss='mean_squared_error',
              optimizer='adam', metrics=['accuracy'])

model2.fit(training_data, target_data, nb_epoch=500, verbose=2)
# Out:
# WARNING:tensorflow:The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Epoch 1/500
#  - 0s - loss: 0.2361 - acc: 0.5000
# Epoch 2/500
#  - 0s - loss: 0.2359 - acc: 0.5000
# Epoch 3/500
#  - 0s - loss: 0.2357 - acc: 0.5000
# Epoch 4/500
#  - 0s - loss: 0.2355 - acc: 0.5000
# Epoch 5/500
#  - 0s - loss: 0.2352 - acc: 0.5000
# Epoch 6/500
#  - 0s - loss: 0.2349 - acc: 0.5000
# Epoch 7/500
#  - 0s - loss: 0.2347 - acc: 0.5000
# Epoch 8/500
#  - 0s - loss: 0.2344 - acc: 0.5000
# Epoch 9/500
#  - 0s - loss: 0.2342 - acc: 0.5000
# Epoch 10/500
#  - 0s - loss: 0.2339 - acc: 0.5000
# Epoch 11/500
#  - 0s - loss: 0.2337 - acc: 0.5000
# Epoch 12/500
#  - 0s - loss: 0.2334 - acc: 0.5000
# Epoch 13/500
#  - 0s - loss: 0.2332 - acc: 0.5000
# Epoch 14/500
#  - 0s - loss: 0.2329 - acc: 0.5000
# Epoch 15/500
#  - 0s - loss: 0.2327 - acc: 0.5000
# Epoch 16/500
#  - 0s - loss: 0.2325 - acc: 0.5000
# Epoch 17/500
#  - 0s - loss: 0.2322 - acc: 0.5000
# Epoch 18/500
# ...

# %%
# As we can see, when we used 1 hidden layer model was able to predict with 100% accuracy after 450 epochs
print(model2.predict(training_data).round())
# Out:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]

# %%
# Printing network parameters:
model2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_10 (Dense)             (None, 8)                 24
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 9
# ...
# Total params: 33
# Trainable params: 33
# Non-trainable params: 0
# _________________________________________________________________
